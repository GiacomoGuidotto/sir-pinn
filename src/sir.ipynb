# %% [markdown]
# # SIR model with constant transmission rate
#
# Solving the SIR model with constant transmission rate $\beta$ and recovery rate $\delta$.
#
# $$
# \begin{cases}
# \frac{dS}{dt} &= -\frac{\beta}{N} I S, \\
# \frac{dI}{dt} &= \frac{\beta}{N} I S - \delta I, \\
# \frac{dR}{dt} &= \delta I,
# \end{cases}
# $$
#
# where $t \in [0, 90]$ and with the initial conditions $S(0) = N - 1$, $I(0) = 1$, and $R(0) = 0$.

# %% [markdown]
# ## Environment Setup
#
# Load .env file, which specifies which backend DeepXDE should use

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import torch
import deepxde as dde
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.interpolate import interp1d

# %% [markdown]
# Log framework versions, expected to match the environment.yaml

# %%
print("using PyTorch version:", torch.__version__)
print("using DeepXDE version:", dde.__version__)
# Out:
# using PyTorch version: 2.5.1
# using DeepXDE version: 1.12.2

# %% [markdown]
# Enable latex in matplotlib and set seaborn theme.

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sns.set_theme(style="darkgrid")

# %% [markdown]
# Set random seed for reproducibility

# %%
seed = 2322

np.random.seed(seed)
torch.manual_seed(seed)
dde.config.set_random_seed(seed)

# %% [markdown]
# ## Generate synthetic data
#
# Building a SIR model to generate a discrete synthetic dataset in a closed time interval.
#
# This dataset will be used as a starting point for creating both the true solution used during the l2 regularization term and observed data used during the training of the network.
#
# The following parameters are used (using Italy as reference):

# %%
N = 56e6  # total population
delta = 1 / 5  # recovery rate (1 / mean infectious period)
r0 = 3.0  # basic reproduction number
beta = delta * r0  # transmission rate

# %% [markdown]
# The following time interval is used:

# %%
T0, TF = 0, 90  # (days)

# %% [markdown]
# Define the SIR model and the initial conditions.

# %%
def SIR(x, t, delta, beta, N):
  S, I, R = x
  _lambda = beta * I / N
  dSdt = -_lambda * S
  dIdt = _lambda * S - delta * I
  dRdt = delta * I
  return [dSdt, dIdt, dRdt]


S0 = N - 1
I0 = 1
R0 = 0

# %% [markdown]
# Define a function to generate a discrete solution for the SIR model based on a time interval.

# %%
def solve_sir(t):
  x = odeint(SIR, [S0, I0, R0], t, args=(delta, beta, N))
  S = x[:, 0]
  I = x[:, 1]
  R = x[:, 2]
  return S, I, R

# %% [markdown]
# Generate a synthetic dataset and a synthetic observation of $I(t)$ by adding some noise to the true solution.

# %%
t_data = np.linspace(T0, TF, TF - T0)
S_data, I_data, R_data = solve_sir(t_data)

I_obs = np.random.poisson(I_data)

# %% [markdown]
# Plot the synthetic dataset and the observed $I(t)$.

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

sns.lineplot(x=t_data, y=S_data, ax=ax, label=r"$S(t)$")
sns.lineplot(x=t_data, y=I_data, ax=ax, label=r"$I(t)$")
sns.lineplot(x=t_data, y=R_data, ax=ax, label=r"$R(t)$")
sns.scatterplot(x=t_data, y=I_obs, ax=ax, label=r"Observed $I(t)$")

plt.title(
  r"SIR Model with $\beta = {:.2f}$ and $\delta = {:.2f}$".format(beta, delta)
)
plt.xlabel(r"Time $t$")
plt.ylabel(r"Population")

plt.savefig("data/synthetic_data.png")

# %% [markdown]
# ### Data Scaling
#
# Scale both dataset and observation by a constant $C$ and into a time interval $[0, 1]$.
#
# This is necessary to avoid numerical instability during the training of the network.

# %%
C = 1e5

t_data_sc = t_data / TF
I_data_sc = I_data / C

I_obs_sc = I_obs / C

# %% [markdown]
# Create a function to compute the true solution for any time point.
#
# It uses an interpolation function applied on a more dense time interval.

# %%
t_dense = np.linspace(T0, TF, 1000)
S_dense, I_dense, R_dense = solve_sir(t_dense)

t_dense_sc = t_dense / TF
S_dense_sc = S_dense / C
I_dense_sc = I_dense / C
R_dense_sc = R_dense / C

S_interp = interp1d(t_dense_sc, S_dense, kind='cubic', fill_value="extrapolate")
I_interp = interp1d(t_dense_sc, I_dense, kind='cubic', fill_value="extrapolate")
R_interp = interp1d(t_dense_sc, R_dense, kind='cubic', fill_value="extrapolate")


def true_solution(t):
  t = t.flatten()
  S = S_interp(t) / C
  I = I_interp(t) / C
  R = R_interp(t) / C
  return np.hstack((S.reshape(-1, 1), I.reshape(-1, 1), R.reshape(-1, 1)))

# %% [markdown]
# ## Modelling the Network

# %% [markdown]
# Define the time domain geometry, scaled to the range [0, 1].

# %%
geom = dde.geometry.TimeDomain(T0 / TF, TF / TF)

# %% [markdown]
# Define the beta parameter as a trainable variable with initial guess.

# %%
beta_var = dde.Variable(0.5)

# %% [markdown]
# Define the ODE system.

# %%
C1 = (TF - T0) * C / N
C2 = (TF - T0) * delta


def ode_system(t, y):
  S = y[:, 0:1]
  I = y[:, 1:2]
  _R = y[:, 2:3]
  dS_t = dde.grad.jacobian(y, t, i=0)
  dI_t = dde.grad.jacobian(y, t, i=1)
  dR_t = dde.grad.jacobian(y, t, i=2)

  res_s = dS_t - (- C1 * beta_var * I * S)
  res_i = dI_t - (C1 * beta_var * I * S - C2 * I)
  res_r = dR_t - (C2 * I)
  return torch.cat([res_s, res_i, res_r], dim=1)

# %% [markdown]
# Define the initial condition.

# %%
def boundary_ic(_, on_initial):
  return on_initial


ic_S = dde.icbc.IC(geom, lambda t: (N - 1) / C, boundary_ic, component=0)
ic_I = dde.icbc.IC(geom, lambda t: 1 / C, boundary_ic, component=1)
ic_R = dde.icbc.IC(geom, lambda t: 0.0, boundary_ic, component=2)

# %% [markdown]
# Define the boundary condition using the observed $I(t)$ data.

# %%
observe_I = dde.icbc.PointSetBC(
  t_data_sc.reshape(-1, 1),
  I_obs_sc.reshape(-1, 1),
  component=1  # index of I(t) in the network output
)

# %% [markdown]
# Define the ODE problem with the ICs and BCs.
#
# We use 2000 points inside the domain and 2 points on the boundary (the start and the end of the time domain).
#
# We use the synthetic (and scaled) time domain to define the points where the data is observed.

# %%
data = dde.data.PDE(
  geom,
  ode_system,
  [ic_S, ic_I, ic_R, observe_I],
  num_domain=2000,
  num_boundary=2,
  anchors=t_data_sc.reshape(-1, 1),
  solution=true_solution,
  num_test=100
)

# %% [markdown]
# Define the network.

# %%
layer_size = [1] + [50] * 3 + [3]
activation = "tanh"
initializer = "Glorot uniform"

net = dde.nn.FNN(layer_size, activation, initializer)

# %% [markdown]
# Define the model, including the beta parameter as an external trainable variable.

# %%
model = dde.Model(data, net)

model.compile(
  optimizer="adam",
  lr=0.001,
  loss_weights=[1] * 5,
  external_trainable_variables=[beta_var],
  metrics=["l2 relative error"]
)
# Out:
# Compiling model...
# 'compile' took 0.000335 s

# %% [markdown]
# Train the model.

# %%
loss_history, train_state = model.train(iterations=50000)
# Out:
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 0         [6.94e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [6.91e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [1.00e+00]
# 1000      [5.28e+00, 2.47e+05, 3.46e-02, 8.90e-05, 3.17e+03]    [5.28e+00, 2.47e+05, 3.46e-02, 8.90e-05, 3.17e+03]    [9.33e-01]
# 2000      [5.33e+00, 2.01e+05, 3.54e-02, 2.37e-05, 3.17e+03]    [5.33e+00, 2.01e+05, 3.54e-02, 2.37e-05, 3.17e+03]    [8.89e-01]
# 3000      [8.60e+00, 1.61e+05, 9.15e-02, 3.80e-06, 3.16e+03]    [8.54e+00, 1.61e+05, 9.15e-02, 3.80e-06, 3.16e+03]    [8.53e-01]
# 4000      [4.12e+01, 1.26e+05, 4.64e-02, 4.92e-05, 2.97e+03]    [4.15e+01, 1.26e+05, 4.64e-02, 4.92e-05, 2.97e+03]    [8.00e-01]
# 5000      [7.81e+01, 9.63e+04, 4.28e-02, 6.50e-06, 2.84e+03]    [7.88e+01, 9.63e+04, 4.28e-02, 6.50e-06, 2.84e+03]    [7.59e-01]
# 6000      [1.09e+02, 7.09e+04, 1.24e-01, 2.42e-06, 2.66e+03]    [1.09e+02, 7.09e+04, 1.24e-01, 2.42e-06, 2.66e+03]    [7.03e-01]
# 7000      [1.21e+02, 4.99e+04, 2.93e-01, 3.20e-06, 2.52e+03]    [1.22e+02, 4.99e+04, 2.93e-01, 3.20e-06, 2.52e+03]    [6.63e-01]
# 8000      [1.36e+02, 3.31e+04, 3.99e-01, 1.34e-06, 2.38e+03]    [1.37e+02, 3.31e+04, 3.99e-01, 1.34e-06, 2.38e+03]    [6.25e-01]
# 9000      [1.39e+02, 2.02e+04, 3.43e-01, 1.62e-07, 2.29e+03]    [1.39e+02, 2.02e+04, 3.43e-01, 1.62e-07, 2.29e+03]    [6.06e-01]
# 10000     [1.36e+02, 1.10e+04, 5.39e-01, 2.10e-07, 2.16e+03]    [1.36e+02, 1.10e+04, 5.39e-01, 2.10e-07, 2.16e+03]    [5.76e-01]
# 11000     [1.36e+02, 4.98e+03, 4.34e-01, 6.05e-08, 2.08e+03]    [1.36e+02, 4.98e+03, 4.34e-01, 6.05e-08, 2.08e+03]    [5.68e-01]
# 12000     [1.34e+02, 1.70e+03, 4.65e-01, 5.02e-06, 2.03e+03]    [1.34e+02, 1.70e+03, 4.65e-01, 5.02e-06, 2.03e+03]    [5.67e-01]
# 13000     [1.29e+02, 3.52e+02, 5.00e-01, 1.67e-08, 1.99e+03]    [1.28e+02, 3.52e+02, 5.00e-01, 1.67e-08, 1.99e+03]    [5.68e-01]
# 14000     [1.13e+02, 3.06e+01, 4.84e-01, 1.51e-05, 1.86e+03]    [1.12e+02, 3.06e+01, 4.84e-01, 1.51e-05, 1.86e+03]    [5.36e-01]
# 15000     [1.15e+02, 2.09e-01, 3.72e-01, 7.10e-08, 1.82e+03]    [1.15e+02, 2.09e-01, 3.72e-01, 7.10e-08, 1.82e+03]    [5.30e-01]
# 16000     [1.12e+02, 1.40e-01, 3.30e-01, 2.01e-06, 1.78e+03]    [1.12e+02, 1.40e-01, 3.30e-01, 2.01e-06, 1.78e+03]    [5.20e-01]
# 17000     [9.31e+01, 5.79e-02, 2.45e-01, 8.41e-08, 1.61e+03]    [9.29e+01, 5.79e-02, 2.45e-01, 8.41e-08, 1.61e+03]    [4.70e-01]
# 18000     [8.55e+01, 6.97e-03, 1.73e-01, 1.07e-07, 1.52e+03]    [8.52e+01, 6.97e-03, 1.73e-01, 1.07e-07, 1.52e+03]    [4.45e-01]
# 19000     [7.35e+01, 6.20e-02, 1.14e-01, 7.40e-07, 1.40e+03]    [7.31e+01, 6.20e-02, 1.14e-01, 7.40e-07, 1.40e+03]    [4.11e-01]
# 20000     [2.94e+01, 4.30e-01, 2.09e-01, 6.87e-07, 1.23e+03]    [2.80e+01, 4.30e-01, 2.09e-01, 6.87e-07, 1.23e+03]    [3.55e-01]
# 21000     [3.56e+01, 5.56e-01, 2.95e-02, 3.46e-08, 1.02e+03]    [3.50e+01, 5.56e-01, 2.95e-02, 3.46e-08, 1.02e+03]    [3.13e-01]
# 22000     [2.77e+01, 7.49e-01, 1.31e-02, 5.02e-08, 8.62e+02]    [2.72e+01, 7.49e-01, 1.31e-02, 5.02e-08, 8.62e+02]    [2.75e-01]
# 23000     [2.28e+01, 7.80e-01, 6.44e-03, 2.77e-07, 7.17e+02]    [2.24e+01, 7.80e-01, 6.44e-03, 2.77e-07, 7.17e+02]    [2.40e-01]
# 24000     [1.47e+01, 6.71e-01, 3.22e-03, 3.06e-09, 5.87e+02]    [1.44e+01, 6.71e-01, 3.22e-03, 3.06e-09, 5.87e+02]    [2.08e-01]
# 25000     [1.09e+01, 4.92e-01, 1.62e-03, 5.25e-07, 4.72e+02]    [1.06e+01, 4.92e-01, 1.62e-03, 5.25e-07, 4.72e+02]    [1.79e-01]
# 26000     [7.86e+00, 3.35e-01, 8.75e-04, 1.32e-07, 3.74e+02]    [7.58e+00, 3.35e-01, 8.75e-04, 1.32e-07, 3.74e+02]    [1.54e-01]
# 27000     [5.82e+00, 2.08e-01, 5.32e-04, 6.93e-08, 2.93e+02]    [5.64e+00, 2.08e-01, 5.32e-04, 6.93e-08, 2.93e+02]    [1.31e-01]
# 28000     [5.52e+00, 1.27e-01, 3.32e-04, 8.80e-07, 2.28e+02]    [5.65e+00, 1.27e-01, 3.32e-04, 8.80e-07, 2.28e+02]    [1.12e-01]
# 29000     [6.10e+00, 7.85e-02, 1.69e-04, 1.17e-06, 1.76e+02]    [6.69e+00, 7.85e-02, 1.69e-04, 1.17e-06, 1.76e+02]    [9.63e-02]
# 30000     [2.78e+00, 5.12e-02, 1.05e-04, 8.29e-09, 1.36e+02]    [3.43e+00, 5.12e-02, 1.05e-04, 8.29e-09, 1.36e+02]    [8.30e-02]
# 31000     [2.54e+00, 3.49e-02, 6.17e-05, 3.08e-07, 1.06e+02]    [3.02e+00, 3.49e-02, 6.17e-05, 3.08e-07, 1.06e+02]    [7.17e-02]
# 32000     [2.15e+00, 2.40e-02, 4.93e-05, 1.19e-08, 8.22e+01]    [2.33e+00, 2.40e-02, 4.93e-05, 1.19e-08, 8.22e+01]    [6.22e-02]
# 33000     [3.11e+00, 1.74e-02, 5.05e-05, 4.38e-06, 6.41e+01]    [3.05e+00, 1.74e-02, 5.05e-05, 4.38e-06, 6.41e+01]    [5.43e-02]
# 34000     [1.82e+00, 1.31e-02, 2.97e-05, 2.33e-07, 5.00e+01]    [1.57e+00, 1.31e-02, 2.97e-05, 2.33e-07, 5.00e+01]    [4.73e-02]
# 35000     [1.52e+00, 9.91e-03, 2.19e-05, 2.58e-07, 3.92e+01]    [1.23e+00, 9.91e-03, 2.19e-05, 2.58e-07, 3.92e+01]    [4.14e-02]
# 36000     [2.10e+00, 7.30e-03, 8.59e-06, 1.61e-06, 3.07e+01]    [1.83e+00, 7.30e-03, 8.59e-06, 1.61e-06, 3.07e+01]    [3.63e-02]
# 37000     [1.16e+00, 5.59e-03, 9.81e-06, 6.17e-08, 2.43e+01]    [9.63e-01, 5.59e-03, 9.81e-06, 6.17e-08, 2.43e+01]    [3.21e-02]
# 38000     [9.70e-01, 4.21e-03, 8.49e-06, 1.53e-07, 1.93e+01]    [8.26e-01, 4.21e-03, 8.49e-06, 1.53e-07, 1.93e+01]    [2.84e-02]
# 39000     [8.63e-01, 3.24e-03, 7.38e-06, 5.71e-08, 1.54e+01]    [7.72e-01, 3.24e-03, 7.38e-06, 5.71e-08, 1.54e+01]    [2.52e-02]
# 40000     [7.49e-01, 2.57e-03, 4.64e-06, 6.04e-09, 1.23e+01]    [6.88e-01, 2.57e-03, 4.64e-06, 6.04e-09, 1.23e+01]    [2.24e-02]
# 41000     [7.03e-01, 1.99e-03, 3.63e-06, 5.13e-08, 9.79e+00]    [6.62e-01, 1.99e-03, 3.63e-06, 5.13e-08, 9.79e+00]    [1.99e-02]
# 42000     [1.74e+00, 1.46e-03, 9.32e-06, 6.30e-07, 7.88e+00]    [1.75e+00, 1.46e-03, 9.32e-06, 6.30e-07, 7.88e+00]    [1.78e-02]
# 43000     [5.54e-01, 1.16e-03, 3.27e-06, 9.46e-08, 6.32e+00]    [5.29e-01, 1.16e-03, 3.27e-06, 9.46e-08, 6.32e+00]    [1.59e-02]
# 44000     [5.93e-01, 8.55e-04, 3.59e-06, 2.37e-07, 5.11e+00]    [5.80e-01, 8.55e-04, 3.59e-06, 2.37e-07, 5.11e+00]    [1.42e-02]
# 45000     [4.18e+00, 8.26e-04, 1.07e-07, 3.97e-06, 4.07e+00]    [4.23e+00, 8.26e-04, 1.07e-07, 3.97e-06, 4.07e+00]    [1.26e-02]
# 46000     [7.05e+00, 6.20e-04, 5.35e-08, 7.51e-06, 3.26e+00]    [7.09e+00, 6.20e-04, 5.35e-08, 7.51e-06, 3.26e+00]    [1.12e-02]
# 47000     [3.92e-01, 5.16e-04, 2.12e-06, 4.39e-09, 2.71e+00]    [3.61e-01, 5.16e-04, 2.12e-06, 4.39e-09, 2.71e+00]    [1.03e-02]
# 48000     [1.26e+00, 3.56e-04, 1.04e-07, 9.16e-07, 2.19e+00]    [1.25e+00, 3.56e-04, 1.04e-07, 9.16e-07, 2.19e+00]    [9.17e-03]
# 49000     [5.22e+00, 3.31e-04, 7.31e-06, 3.43e-06, 1.87e+00]    [5.24e+00, 3.31e-04, 7.31e-06, 3.43e-06, 1.87e+00]    [8.50e-03]
# 50000     [2.97e-01, 2.68e-04, 1.10e-06, 2.60e-09, 1.47e+00]    [2.62e-01, 2.68e-04, 1.10e-06, 2.60e-09, 1.47e+00]    [7.50e-03]
#
# Best model at step 50000:
#   train loss: 1.77e+00
#   test loss: 1.73e+00
#   test metric: [7.50e-03]
#
# 'train' took 197.111825 s

# %% [markdown]
# Visualize and save the loss history.

# %%
# disable latex for deepxde plots
plt.rc('text', usetex=False)

dde.saveplot(
  loss_history,
  train_state,
  issave=True,
  isplot=True,
  output_dir="data"
)
# Out:
# Saving loss history to data/loss.dat ...
# Saving training data to data/train.dat ...
# Saving test data to data/test.dat ...
