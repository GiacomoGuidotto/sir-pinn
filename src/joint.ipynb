# %% [markdown]
# # SIR model - Joint Approach
#
# Solving the SIR model with constant transmission rate $\beta$ and recovery rate $\delta$.
#
# $$
# \begin{cases}
# \frac{dS}{dt} &= -\frac{\beta}{N} I S, \\
# \frac{dI}{dt} &= \frac{\beta}{N} I S - \delta I, \\
# \frac{dR}{dt} &= \delta I,
# \end{cases}
# $$
#
# where $t \in [0, 90]$ and with the initial conditions $S(0) = N - 1$, $I(0) = 1$, and $R(0) = 0$.

# %% [markdown]
# ## Environment Setup
#
# Load .env file, which specifies which backend DeepXDE should use

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import torch
import deepxde as dde
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.interpolate import interp1d

# %% [markdown]
# Enable latex in matplotlib and set seaborn theme.

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sns.set_theme(style="darkgrid")

# %% [markdown]
# Set random seed for reproducibility

# %%
seed = 2322

np.random.seed(seed)
torch.manual_seed(seed)
dde.config.set_random_seed(seed)

# %% [markdown]
# ## Synthetic data generation
#
# Building a SIR model to generate a discrete synthetic dataset in a closed time interval.
#
# This dataset will be used as a starting point for creating both the true solution used during the l2 regularization term and observed data used during the training of the network.
#
# ### System configuration
#
# The following parameters are used (using Italy as reference):

# %%
N = 56e6  # total population
delta = 1 / 5  # recovery rate (1 / mean infectious period)
r0 = 3.0  # basic reproduction number
beta = delta * r0  # transmission rate

# %% [markdown]
# The following time interval is used:

# %%
T0, TF = 0, 90  # (days)

# %% [markdown]
# ### System definition
#
# Define the SIR model and the initial conditions.

# %%
def SIR(x, t, delta, beta, N):
  S, I, R = x
  _lambda = beta * I / N
  dSdt = -_lambda * S
  dIdt = _lambda * S - delta * I
  dRdt = delta * I
  return [dSdt, dIdt, dRdt]


S0 = N - 1
I0 = 1
R0 = 0

# %% [markdown]
# Define a function to generate a discrete solution for the SIR model based on a time interval.

# %%
def solve_sir(t):
  x = odeint(SIR, [S0, I0, R0], t, args=(delta, beta, N))
  S = x[:, 0]
  I = x[:, 1]
  R = x[:, 2]
  return S, I, R

# %% [markdown]
# ### Data generation
#
# Generate a synthetic dataset and a synthetic observation of $I(t)$ by adding some noise to the true solution.

# %%
t_train = np.linspace(T0, TF, TF - T0 + 1)
S_data, I_data, R_data = solve_sir(t_train)

I_train = np.random.poisson(I_data)

# %% [markdown]
# Plot the synthetic dataset and the observed $I(t)$.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_train, y=S_data, label=r"$S(t)$")
sns.lineplot(x=t_train, y=I_data, label=r"$I(t)$")
sns.lineplot(x=t_train, y=R_data, label=r"$R(t)$")
sns.scatterplot(x=t_train, y=I_train, label=r"Observed $I(t)$")

plt.title(
  r"SIR Model with $\beta = {:.2f}$ and $\delta = {:.2f}$".format(beta, delta)
)
plt.xlabel(r"Time (days)")
plt.ylabel(r"Population")

plt.savefig("data/joint/synthetic_data.png")

# %% [markdown]
# ## Data Scaling
#
# Scale both dataset and observation by a constant $C$ and into a time interval $[0, 1]$.
#
# This is necessary to avoid numerical instability during the training of the network.
#
# Define the scaling and unscaling functions.

# %%
C = 1e5


def scale_time(t):
  return t / TF


def unscale_time(t):
  return t * TF


def scale_population(x):
  return x / C


def unscale_population(x):
  return x * C

# %% [markdown]
# From now on, we will only use the scaled data.

# %%
t_train = scale_time(t_train.reshape(-1, 1))

I_train = scale_population(I_train.reshape(-1, 1))

# %% [markdown]
# ## True Solution
#
# Create a function to compute the true solution for any time point.
#
# It uses an interpolation function applied on a more dense time interval.

# %%
t_dense = np.linspace(T0, TF, 1000)
S_dense, I_dense, R_dense = solve_sir(t_dense)

t_dense = scale_time(t_dense)
S_dense = scale_population(S_dense)
I_dense = scale_population(I_dense)
R_dense = scale_population(R_dense)

S_interp = interp1d(t_dense, S_dense, kind='cubic', fill_value="extrapolate")
I_interp = interp1d(t_dense, I_dense, kind='cubic', fill_value="extrapolate")
R_interp = interp1d(t_dense, R_dense, kind='cubic', fill_value="extrapolate")


def true_solution(t):
  t = t.flatten()
  S = S_interp(t)
  I = I_interp(t)
  R = R_interp(t)
  return np.hstack((S.reshape(-1, 1), I.reshape(-1, 1), R.reshape(-1, 1)))

# %% [markdown]
# ## Modelling a Joint Approach
#
# Define a PINN that tries to solve the SIR model by reducing at the same time the error generated by the observed data, the error generated by the ODE system, and the error generated by initial conditions mismatch.
#
# ### Network configuration

# %%
layer_size = [1] + [50] * 3 + [3]
activation = "tanh"
initializer = "Glorot uniform"

optimizer = "adam"
lr = 0.001

iterations = 50000

# %% [markdown]
# ### Network definition
#
# Define the time domain geometry, scaled to the range [0, 1].

# %%
geom = dde.geometry.TimeDomain(scale_time(T0), scale_time(TF))

# %% [markdown]
# Define the beta parameter as a trainable variable with initial guess.

# %%
beta_var = dde.Variable(0.5)

# %% [markdown]
# Define the ODE system, adjusted to use the scaled data.

# %%
C1 = (TF - T0) * C / N
C2 = (TF - T0) * delta


def ode_system(t, y):
  S = y[:, 0:1]
  I = y[:, 1:2]
  _ = y[:, 2:3]
  dS_t = dde.grad.jacobian(y, t, i=0)
  dI_t = dde.grad.jacobian(y, t, i=1)
  dR_t = dde.grad.jacobian(y, t, i=2)

  res_s = dS_t - (- C1 * beta_var * I * S)
  res_i = dI_t - (C1 * beta_var * I * S - C2 * I)
  res_r = dR_t - (C2 * I)
  return torch.cat([res_s, res_i, res_r], dim=1)

# %% [markdown]
# Define the initial condition.

# %%
def boundary(_, on_initial):
  return on_initial


ic_S = dde.icbc.IC(geom, lambda t: scale_population(S0), boundary, component=0)
ic_I = dde.icbc.IC(geom, lambda t: scale_population(I0), boundary, component=1)
ic_R = dde.icbc.IC(geom, lambda t: scale_population(R0), boundary, component=2)

# %% [markdown]
# Define the boundary condition using the observed $I(t)$ data.

# %%
observe_I = dde.icbc.PointSetBC(t_train, I_train, component=1)

# %% [markdown]
# Define the ODE problem with the ICs and BCs.
#
# We use 90 points inside the domain and 2 points on the boundary (the start and the end of the time domain).
#
# We use the synthetic (and scaled) time domain to define the points where the data is observed.

# %%
data = dde.data.PDE(
  geom,
  ode_system,
  [ic_S, ic_I, ic_R, observe_I],
  num_domain=90,
  num_boundary=2,
  anchors=t_train,
  solution=true_solution,
  num_test=10
)

# %% [markdown]
# Define the network.

# %%
net = dde.nn.pytorch.FNN(layer_size, activation, initializer)

# %% [markdown]
# Define the model, including the beta parameter as an external trainable variable.

# %%
model = dde.Model(data, net)

variable = dde.callbacks.VariableValue(
  beta_var,
  period=1000,
  filename="data/joint/beta_var.dat",
)

model.compile(
  optimizer=optimizer,
  lr=lr,
  loss_weights=[1] * 5,
  external_trainable_variables=[beta_var],
  metrics=["l2 relative error"]
)
# Out:
# Compiling model...
# 'compile' took 0.000552 s

# %% [markdown]
# Train the model.

# %%
loss_history, train_state = model.train(
  iterations=iterations,
  callbacks=[variable]
)
# Out:
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 0         [6.90e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [6.70e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [1.00e+00]
# 1000      [5.27e+00, 2.47e+05, 3.45e-02, 8.49e-05, 3.17e+03]    [5.27e+00, 2.47e+05, 3.45e-02, 8.49e-05, 3.17e+03]    [9.31e-01]
# 2000      [5.33e+00, 2.01e+05, 3.53e-02, 2.29e-05, 3.17e+03]    [5.34e+00, 2.01e+05, 3.53e-02, 2.29e-05, 3.17e+03]    [8.87e-01]
# 3000      [8.51e+00, 1.61e+05, 9.04e-02, 3.93e-06, 3.16e+03]    [7.97e+00, 1.61e+05, 9.04e-02, 3.93e-06, 3.16e+03]    [8.49e-01]
# 4000      [4.13e+01, 1.26e+05, 4.28e-02, 2.30e-05, 2.97e+03]    [4.44e+01, 1.26e+05, 4.28e-02, 2.30e-05, 2.97e+03]    [7.96e-01]
# 5000      [7.63e+01, 9.63e+04, 3.91e-02, 7.36e-06, 2.85e+03]    [8.23e+01, 9.63e+04, 3.91e-02, 7.36e-06, 2.85e+03]    [7.54e-01]
# 6000      [1.06e+02, 7.09e+04, 1.08e-01, 3.72e-06, 2.69e+03]    [1.14e+02, 7.09e+04, 1.08e-01, 3.72e-06, 2.69e+03]    [7.05e-01]
# 7000      [1.24e+02, 4.99e+04, 1.85e-01, 1.63e-06, 2.55e+03]    [1.33e+02, 4.99e+04, 1.85e-01, 1.63e-06, 2.55e+03]    [6.63e-01]
# 8000      [1.39e+02, 3.31e+04, 4.02e-01, 8.06e-07, 2.40e+03]    [1.48e+02, 3.31e+04, 4.02e-01, 8.06e-07, 2.40e+03]    [6.21e-01]
# 9000      [1.40e+02, 2.02e+04, 3.03e-01, 1.98e-07, 2.29e+03]    [1.52e+02, 2.02e+04, 3.03e-01, 1.98e-07, 2.29e+03]    [5.98e-01]
# 10000     [1.41e+02, 1.10e+04, 3.81e-01, 7.16e-08, 2.15e+03]    [1.53e+02, 1.10e+04, 3.81e-01, 7.16e-08, 2.15e+03]    [5.66e-01]
# 11000     [1.39e+02, 4.98e+03, 3.60e-01, 7.90e-07, 2.08e+03]    [1.50e+02, 4.98e+03, 3.60e-01, 7.90e-07, 2.08e+03]    [5.59e-01]
# 12000     [1.37e+02, 1.70e+03, 3.96e-01, 9.01e-08, 2.03e+03]    [1.46e+02, 1.70e+03, 3.96e-01, 9.01e-08, 2.03e+03]    [5.58e-01]
# 13000     [1.36e+02, 3.53e+02, 4.23e-01, 7.26e-10, 1.98e+03]    [1.43e+02, 3.53e+02, 4.23e-01, 7.26e-10, 1.98e+03]    [5.58e-01]
# 14000     [1.21e+02, 3.05e+01, 3.79e-01, 6.47e-08, 1.85e+03]    [1.29e+02, 3.05e+01, 3.79e-01, 6.47e-08, 1.85e+03]    [5.27e-01]
# 15000     [1.20e+02, 2.10e-01, 3.43e-01, 1.48e-06, 1.82e+03]    [1.28e+02, 2.10e-01, 3.43e-01, 1.48e-06, 1.82e+03]    [5.21e-01]
# 16000     [1.17e+02, 1.28e-01, 3.14e-01, 8.06e-06, 1.78e+03]    [1.26e+02, 1.28e-01, 3.14e-01, 8.06e-06, 1.78e+03]    [5.11e-01]
# 17000     [9.86e+01, 5.74e-02, 2.28e-01, 3.11e-09, 1.61e+03]    [1.09e+02, 5.74e-02, 2.28e-01, 3.11e-09, 1.61e+03]    [4.62e-01]
# 18000     [8.99e+01, 4.71e-03, 1.64e-01, 1.11e-08, 1.52e+03]    [9.74e+01, 4.71e-03, 1.64e-01, 1.11e-08, 1.52e+03]    [4.38e-01]
# 19000     [7.55e+01, 8.33e-02, 1.06e-01, 7.73e-08, 1.40e+03]    [7.78e+01, 8.33e-02, 1.06e-01, 7.73e-08, 1.40e+03]    [4.04e-01]
# 20000     [4.78e+01, 2.97e-01, 5.20e-02, 2.38e-07, 1.17e+03]    [4.39e+01, 2.97e-01, 5.20e-02, 2.38e-07, 1.17e+03]    [3.44e-01]
# 21000     [3.96e+01, 5.94e-01, 2.61e-02, 2.91e-06, 1.01e+03]    [3.53e+01, 5.94e-01, 2.61e-02, 2.91e-06, 1.01e+03]    [3.05e-01]
# 22000     [2.91e+01, 7.72e-01, 1.25e-02, 1.19e-06, 8.53e+02]    [2.46e+01, 7.72e-01, 1.25e-02, 1.19e-06, 8.53e+02]    [2.69e-01]
# 23000     [1.08e+01, 1.67e-01, 8.25e-03, 3.45e-07, 6.89e+02]    [6.85e+00, 1.67e-01, 8.25e-03, 3.45e-07, 6.89e+02]    [2.25e-01]
# 24000     [8.95e+00, 3.47e-01, 2.53e-03, 1.06e-08, 5.38e+02]    [5.75e+00, 3.47e-01, 2.53e-03, 1.06e-08, 5.38e+02]    [1.92e-01]
# 25000     [7.75e+00, 2.69e-01, 1.13e-03, 1.06e-06, 4.26e+02]    [4.61e+00, 2.69e-01, 1.13e-03, 1.06e-06, 4.26e+02]    [1.64e-01]
# 26000     [5.24e+00, 1.85e-01, 6.14e-04, 1.15e-07, 3.32e+02]    [2.69e+00, 1.85e-01, 6.14e-04, 1.15e-07, 3.32e+02]    [1.40e-01]
# 27000     [3.66e+00, 1.31e-01, 2.99e-04, 1.80e-09, 2.54e+02]    [2.32e+00, 1.31e-01, 2.99e-04, 1.80e-09, 2.54e+02]    [1.18e-01]
# 28000     [3.01e+00, 9.22e-02, 1.48e-04, 1.48e-08, 1.91e+02]    [1.68e+00, 9.22e-02, 1.48e-04, 1.48e-08, 1.91e+02]    [9.95e-02]
# 29000     [2.71e+00, 6.55e-02, 6.70e-05, 2.49e-07, 1.41e+02]    [3.37e+00, 6.55e-02, 6.70e-05, 2.49e-07, 1.41e+02]    [8.33e-02]
# 30000     [4.48e+00, 4.57e-02, 3.91e-05, 1.00e-10, 1.02e+02]    [7.29e+00, 4.57e-02, 3.91e-05, 1.00e-10, 1.02e+02]    [6.91e-02]
# 31000     [1.71e+00, 3.29e-02, 5.07e-06, 1.38e-07, 7.34e+01]    [1.88e+00, 3.29e-02, 5.07e-06, 1.38e-07, 7.34e+01]    [5.74e-02]
# 32000     [1.37e+00, 2.20e-02, 2.27e-06, 4.03e-08, 5.26e+01]    [1.48e+00, 2.20e-02, 2.27e-06, 4.03e-08, 5.26e+01]    [4.79e-02]
# 33000     [1.71e+00, 1.43e-02, 1.29e-07, 1.67e-06, 3.79e+01]    [1.23e+00, 1.43e-02, 1.29e-07, 1.67e-06, 3.79e+01]    [4.01e-02]
# 34000     [4.44e+00, 1.05e-02, 6.03e-06, 4.09e-07, 2.73e+01]    [4.61e+00, 1.05e-02, 6.03e-06, 4.09e-07, 2.73e+01]    [3.39e-02]
# 35000     [1.29e+00, 7.19e-03, 5.03e-06, 2.01e-07, 2.00e+01]    [5.57e-01, 7.19e-03, 5.03e-06, 2.01e-07, 2.00e+01]    [2.88e-02]
# 36000     [2.66e+00, 5.00e-03, 4.56e-07, 9.46e-08, 1.49e+01]    [4.42e+00, 5.00e-03, 4.56e-07, 9.46e-08, 1.49e+01]    [2.46e-02]
# 37000     [1.00e+00, 3.45e-03, 6.32e-06, 3.88e-07, 1.11e+01]    [5.74e-01, 3.45e-03, 6.32e-06, 3.88e-07, 1.11e+01]    [2.11e-02]
# 38000     [2.02e+00, 2.65e-03, 1.17e-05, 2.78e-07, 8.27e+00]    [5.20e-01, 2.65e-03, 1.17e-05, 2.78e-07, 8.27e+00]    [1.81e-02]
# 39000     [2.01e+00, 1.54e-03, 9.04e-06, 1.43e-06, 6.28e+00]    [2.63e+00, 1.54e-03, 9.04e-06, 1.43e-06, 6.28e+00]    [1.56e-02]
# 40000     [5.64e-01, 1.20e-03, 1.26e-05, 9.61e-10, 4.77e+00]    [2.30e-01, 1.20e-03, 1.26e-05, 9.61e-10, 4.77e+00]    [1.36e-02]
# 41000     [1.29e+00, 8.26e-04, 1.05e-05, 2.00e-06, 3.64e+00]    [4.41e-01, 8.26e-04, 1.05e-05, 2.00e-06, 3.64e+00]    [1.19e-02]
# 42000     [2.04e+00, 5.78e-04, 2.43e-05, 2.30e-07, 2.82e+00]    [2.75e+00, 5.78e-04, 2.43e-05, 2.30e-07, 2.82e+00]    [1.04e-02]
# 43000     [1.06e+00, 4.31e-04, 1.02e-05, 3.00e-07, 2.19e+00]    [1.86e+00, 4.31e-04, 1.02e-05, 3.00e-07, 2.19e+00]    [9.11e-03]
# 44000     [3.54e+00, 3.70e-04, 2.77e-05, 6.93e-06, 1.71e+00]    [2.31e+00, 3.70e-04, 2.77e-05, 6.93e-06, 1.71e+00]    [7.80e-03]
# 45000     [1.55e+00, 2.25e-04, 2.33e-05, 4.70e-07, 1.33e+00]    [7.15e-01, 2.25e-04, 2.33e-05, 4.70e-07, 1.33e+00]    [7.07e-03]
# 46000     [3.19e-01, 2.18e-04, 2.44e-05, 1.88e-09, 1.04e+00]    [2.76e-01, 2.18e-04, 2.44e-05, 1.88e-09, 1.04e+00]    [6.21e-03]
# 47000     [4.21e+00, 2.37e-04, 6.25e-05, 9.96e-07, 8.01e-01]    [1.01e+01, 2.37e-04, 6.25e-05, 9.96e-07, 8.01e-01]    [5.42e-03]
# 48000     [3.44e-01, 1.08e-04, 2.24e-05, 1.27e-07, 6.44e-01]    [3.52e-01, 1.08e-04, 2.24e-05, 1.27e-07, 6.44e-01]    [4.88e-03]
# 49000     [2.67e+00, 5.73e-05, 9.03e-06, 1.38e-06, 5.19e-01]    [5.55e+00, 5.73e-05, 9.03e-06, 1.38e-06, 5.19e-01]    [4.39e-03]
# 50000     [3.21e-01, 8.38e-05, 2.78e-05, 1.11e-08, 4.04e-01]    [8.34e-02, 8.38e-05, 2.78e-05, 1.11e-08, 4.04e-01]    [3.85e-03]
#
# Best model at step 50000:
#   train loss: 7.24e-01
#   test loss: 4.87e-01
#   test metric: [3.85e-03]
#
# 'train' took 132.484593 s

# %% [markdown]
# ## Evaluation
#
# Visualize and save the loss history.

# %%
# disable latex for deepxde plots
plt.rc('text', usetex=False)

dde.saveplot(
  loss_history,
  train_state,
  issave=True,
  isplot=True,
  output_dir="data/joint"
)

plt.rc('text', usetex=True)
# Out:
# Saving loss history to data/joint/loss.dat ...
# Saving training data to data/joint/train.dat ...
# Saving test data to data/joint/test.dat ...

# %% [markdown]
# Generate predictions using the trained model and true values from the `true_solution` function.

# %%
t_test = np.linspace(scale_time(T0), scale_time(TF), 100)

y_pred = model.predict(t_test.reshape(-1, 1))
S_pred, I_pred, R_pred = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]

S_true, I_true, R_true = true_solution(t_test.reshape(-1, 1)).T

# %% [markdown]
# Unscale the data for visualization.

# %%
t_test = unscale_time(t_test)
S_true = unscale_population(S_true)
I_true = unscale_population(I_true)
R_true = unscale_population(R_true)

S_pred = unscale_population(S_pred)
I_pred = unscale_population(I_pred)
R_pred = unscale_population(R_pred)

# %% [markdown]
# Plot the true solution and the predicted solution.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_test, y=S_true, label="$S_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=S_pred, label="$S_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=I_true, label="$I_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=I_pred, label="$I_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=R_true, label="$R_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=R_pred, label="$R_{\mathrm{pred}}$", linestyle="--")

plt.xlabel("Time (days)")
plt.ylabel("Population")
plt.title("PINN Prediction vs True Solution")
plt.legend()
plt.savefig("data/joint/predictions.png")
plt.show()
