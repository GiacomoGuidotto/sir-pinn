# %% [markdown]
# # SIR model - Joint Approach
#
# Solving the SIR model with constant transmission rate $\beta$ and recovery rate $\delta$.
#
# $$
# \begin{cases}
# \frac{dS}{dt} &= -\frac{\beta}{N} I S, \\
# \frac{dI}{dt} &= \frac{\beta}{N} I S - \delta I, \\
# \frac{dR}{dt} &= \delta I,
# \end{cases}
# $$
#
# where $t \in [0, 90]$ and with the initial conditions $S(0) = N - 1$, $I(0) = 1$, and $R(0) = 0$.

# %% [markdown]
# ## Environment Setup
#
# Load .env file, which specifies which backend DeepXDE should use

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import torch
import deepxde as dde
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.interpolate import interp1d

# %% [markdown]
# Enable latex in matplotlib and set seaborn theme.

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sns.set_theme(style="darkgrid")

# %% [markdown]
# Set random seed for reproducibility

# %%
seed = 2322

np.random.seed(seed)
torch.manual_seed(seed)
dde.config.set_random_seed(seed)

# %% [markdown]
# ## Synthetic data generation
#
# Building a SIR model to generate a discrete synthetic dataset in a closed time interval.
#
# This dataset will be used as a starting point for creating both the true solution used during the l2 regularization term and observed data used during the training of the network.
#
# ### System configuration
#
# The following parameters are used (using Italy as reference):

# %%
N = 56e6  # total population
delta = 1 / 5  # recovery rate (1 / mean infectious period)
r0 = 3.0  # basic reproduction number
beta = delta * r0  # transmission rate

# %% [markdown]
# The following time interval is used:

# %%
T0, TF = 0, 90  # (days)

# %% [markdown]
# ### System definition
#
# Define the SIR model and the initial conditions.

# %%
def SIR(x, t, delta, beta, N):
  S, I, R = x
  _lambda = beta * I / N
  dSdt = -_lambda * S
  dIdt = _lambda * S - delta * I
  dRdt = delta * I
  return [dSdt, dIdt, dRdt]


S0 = N - 1
I0 = 1
R0 = 0

# %% [markdown]
# Define a function to generate a discrete solution for the SIR model based on a time interval.

# %%
def solve_sir(t):
  x = odeint(SIR, [S0, I0, R0], t, args=(delta, beta, N))
  S = x[:, 0]
  I = x[:, 1]
  R = x[:, 2]
  return S, I, R

# %% [markdown]
# ### Data generation
#
# Generate a synthetic dataset and a synthetic observation of $I(t)$ by adding some noise to the true solution.

# %%
t_train = np.linspace(T0, TF, TF - T0 + 1)
S_data, I_data, R_data = solve_sir(t_train)

I_train = np.random.poisson(I_data)

# %% [markdown]
# Plot the synthetic dataset and the observed $I(t)$.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_train, y=S_data, label=r"$S(t)$")
sns.lineplot(x=t_train, y=I_data, label=r"$I(t)$")
sns.lineplot(x=t_train, y=R_data, label=r"$R(t)$")
sns.scatterplot(x=t_train, y=I_train, label=r"Observed $I(t)$")

plt.title(
  r"SIR Model with $\beta = {:.2f}$ and $\delta = {:.2f}$".format(beta, delta)
)
plt.xlabel(r"Time (days)")
plt.ylabel(r"Population")

plt.savefig("data/joint/synthetic_data.png")

# %% [markdown]
# ## Data Scaling
#
# Scale both dataset and observation by a constant $C$ and into a time interval $[0, 1]$.
#
# This is necessary to avoid numerical instability during the training of the network.
#
# Define the scaling and unscaling functions.

# %%
C = 1e5


def scale_time(t):
  return t / TF


def unscale_time(t):
  return t * TF


def scale_population(x):
  return x / C


def unscale_population(x):
  return x * C

# %% [markdown]
# From now on, we will only use the scaled data.

# %%
t_train = scale_time(t_train.reshape(-1, 1))

I_train = scale_population(I_train.reshape(-1, 1))

# %% [markdown]
# ## True Solution
#
# Create a function to compute the true solution for any time point.
#
# It uses an interpolation function applied on a more dense time interval.

# %%
t_dense = np.linspace(T0, TF, 1000)
S_dense, I_dense, R_dense = solve_sir(t_dense)

t_dense = scale_time(t_dense)
S_dense = scale_population(S_dense)
I_dense = scale_population(I_dense)
R_dense = scale_population(R_dense)

S_interp = interp1d(t_dense, S_dense, kind='cubic', fill_value="extrapolate")
I_interp = interp1d(t_dense, I_dense, kind='cubic', fill_value="extrapolate")
R_interp = interp1d(t_dense, R_dense, kind='cubic', fill_value="extrapolate")


def true_solution(t):
  t = t.flatten()
  S = S_interp(t)
  I = I_interp(t)
  R = R_interp(t)
  return np.hstack((S.reshape(-1, 1), I.reshape(-1, 1), R.reshape(-1, 1)))

# %% [markdown]
# ## Modelling a Joint Approach
#
# Define a PINN that tries to solve the SIR model by reducing at the same time the error generated by the observed data, the error generated by the ODE system, and the error generated by initial conditions mismatch.
#
# ### Network configuration

# %%
layer_size = [1] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"

optimizer = "adam"
lr = 0.001

iterations = 50000

# %% [markdown]
# ### Network definition
#
# Define the time domain geometry, scaled to the range [0, 1].

# %%
geom = dde.geometry.TimeDomain(scale_time(T0), scale_time(TF))

# %% [markdown]
# Define the beta parameter as a trainable variable with initial guess.

# %%
beta_var = dde.Variable(0.5)

# %% [markdown]
# Define the ODE system, adjusted to use the scaled data.

# %%
C1 = (TF - T0) * C / N
C2 = (TF - T0) * delta


def ode_system(t, y):
  S = y[:, 0:1]
  I = y[:, 1:2]
  _ = y[:, 2:3]
  dS_t = dde.grad.jacobian(y, t, i=0)
  dI_t = dde.grad.jacobian(y, t, i=1)
  dR_t = dde.grad.jacobian(y, t, i=2)

  res_s = dS_t - (- C1 * beta_var * I * S)
  res_i = dI_t - (C1 * beta_var * I * S - C2 * I)
  res_r = dR_t - (C2 * I)
  return torch.cat([res_s, res_i, res_r], dim=1)

# %% [markdown]
# Define the initial condition.

# %%
def boundary(_, on_initial):
  return on_initial


ic_S = dde.icbc.IC(geom, lambda t: scale_population(S0), boundary, component=0)
ic_I = dde.icbc.IC(geom, lambda t: scale_population(I0), boundary, component=1)
ic_R = dde.icbc.IC(geom, lambda t: scale_population(R0), boundary, component=2)

# %% [markdown]
# Define the boundary condition using the observed $I(t)$ data.

# %%
observe_I = dde.icbc.PointSetBC(t_train, I_train, component=1)

# %% [markdown]
# Define the ODE problem with the ICs and BCs.
#
# We use 90 points inside the domain and 2 points on the boundary (the start and the end of the time domain).
#
# We use the synthetic (and scaled) time domain to define the points where the data is observed.

# %%
data = dde.data.PDE(
  geom,
  ode_system,
  [ic_S, ic_I, ic_R, observe_I],
  num_domain=90,
  num_boundary=2,
  anchors=t_train,
  solution=true_solution,
  num_test=10
)

# %% [markdown]
# Define the network.

# %%
class ThreeNets(torch.nn.Module):
  def __init__(self, layer_size, activation, initializer):
    super().__init__()
    self.net_S = dde.nn.pytorch.FNN(layer_size, activation, initializer)
    self.net_I = dde.nn.pytorch.FNN(layer_size, activation, initializer)
    self.net_R = dde.nn.pytorch.FNN(layer_size, activation, initializer)
    self.regularizer = None

  def forward(self, x):
    S_pred = self.net_S(x)
    I_pred = self.net_I(x)
    R_pred = self.net_R(x)
    return torch.cat([S_pred, I_pred, R_pred], dim=1)


net = ThreeNets(layer_size, activation, initializer)

# %% [markdown]
# Define the model, including the beta parameter as an external trainable variable.

# %%
model = dde.Model(data, net)

variable = dde.callbacks.VariableValue(
  beta_var,
  period=1000,
  filename="data/joint/beta_var.dat",
)

model.compile(
  optimizer=optimizer,
  lr=lr,
  loss_weights=[1] * 5,
  external_trainable_variables=[beta_var],
  metrics=["l2 relative error"]
)
# Out:
# Compiling model...
# 'compile' took 0.000686 s

# %% [markdown]
# Train the model.

# %%
loss_history, train_state = model.train(
  iterations=iterations,
  callbacks=[variable]
)
# Out:
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 0         [1.97e+00, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [1.94e+00, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [1.00e+00]
# 1000      [9.73e+01, 2.47e+05, 4.82e-04, 2.83e-02, 2.74e+03]    [1.07e+02, 2.47e+05, 4.82e-04, 2.83e-02, 2.74e+03]    [8.93e-01]
# 2000      [1.45e+01, 2.01e+05, 2.91e-04, 4.75e-02, 1.99e+03]    [1.27e+01, 2.01e+05, 2.91e-04, 4.75e-02, 1.99e+03]    [7.98e-01]
# 3000      [2.32e+01, 1.61e+05, 8.05e-04, 1.27e-01, 1.52e+03]    [2.84e+01, 1.61e+05, 8.05e-04, 1.27e-01, 1.52e+03]    [7.15e-01]
# 4000      [5.15e+01, 1.27e+05, 7.59e-04, 2.55e-01, 1.15e+03]    [4.73e+01, 1.27e+05, 7.59e-04, 2.55e-01, 1.15e+03]    [6.34e-01]
# 5000      [5.83e+01, 9.71e+04, 1.51e-04, 5.48e-01, 8.63e+02]    [5.99e+01, 9.71e+04, 1.51e-04, 5.48e-01, 8.63e+02]    [5.56e-01]
# 6000      [3.67e+02, 7.17e+04, 3.55e-06, 9.49e-01, 6.28e+02]    [6.11e+02, 7.17e+04, 3.55e-06, 9.49e-01, 6.28e+02]    [4.79e-01]
# 7000      [2.63e+01, 5.06e+04, 7.54e-06, 1.11e+00, 4.51e+02]    [1.89e+01, 5.06e+04, 7.54e-06, 1.11e+00, 4.51e+02]    [4.03e-01]
# 8000      [4.46e+01, 3.36e+04, 2.83e-06, 1.24e+00, 3.17e+02]    [4.08e+01, 3.36e+04, 2.83e-06, 1.24e+00, 3.17e+02]    [3.31e-01]
# 9000      [1.56e+01, 2.06e+04, 6.25e-06, 1.18e+00, 2.21e+02]    [1.04e+01, 2.06e+04, 6.25e-06, 1.18e+00, 2.21e+02]    [2.63e-01]
# 10000     [9.66e+01, 1.12e+04, 1.15e-04, 9.84e-01, 1.52e+02]    [1.27e+02, 1.12e+04, 1.15e-04, 9.84e-01, 1.52e+02]    [1.99e-01]
# 11000     [1.69e+01, 5.17e+03, 7.95e-05, 6.71e-01, 1.07e+02]    [1.63e+01, 5.17e+03, 7.95e-05, 6.71e-01, 1.07e+02]    [1.42e-01]
# 12000     [6.66e+00, 1.81e+03, 2.35e-04, 3.85e-01, 7.95e+01]    [4.60e+00, 1.81e+03, 2.35e-04, 3.85e-01, 7.95e+01]    [9.39e-02]
# 13000     [4.01e+00, 4.06e+02, 3.83e-04, 1.39e-01, 6.25e+01]    [2.89e+00, 4.06e+02, 3.83e-04, 1.39e-01, 6.25e+01]    [5.98e-02]
# 14000     [2.40e+00, 4.29e+01, 4.88e-04, 2.72e-02, 5.10e+01]    [2.27e+00, 4.29e+01, 4.88e-04, 2.72e-02, 5.10e+01]    [4.23e-02]
# 15000     [3.21e+00, 1.33e+00, 6.03e-04, 9.25e-06, 3.67e+01]    [5.26e+00, 1.33e+00, 6.03e-04, 9.25e-06, 3.67e+01]    [3.53e-02]
# 16000     [1.02e+00, 2.22e-04, 4.42e-04, 5.65e-05, 2.74e+01]    [8.10e-01, 2.22e-04, 4.42e-04, 5.65e-05, 2.74e+01]    [3.29e-02]
# 17000     [1.37e+00, 2.33e-03, 2.96e-04, 7.61e-06, 2.34e+01]    [3.48e-01, 2.33e-03, 2.96e-04, 7.61e-06, 2.34e+01]    [3.11e-02]
# 18000     [9.71e-01, 3.78e-03, 2.01e-04, 5.89e-06, 2.10e+01]    [3.41e-01, 3.78e-03, 2.01e-04, 5.89e-06, 2.10e+01]    [2.94e-02]
# 19000     [8.39e-01, 5.83e-03, 1.85e-04, 2.20e-06, 1.83e+01]    [5.73e-01, 5.83e-03, 1.85e-04, 2.20e-06, 1.83e+01]    [2.73e-02]
# 20000     [6.97e-01, 6.06e-03, 1.31e-04, 4.24e-07, 1.66e+01]    [6.31e-01, 6.06e-03, 1.31e-04, 4.24e-07, 1.66e+01]    [2.59e-02]
# 21000     [1.46e+01, 7.92e-04, 1.09e-04, 1.76e-04, 1.50e+01]    [1.90e+01, 7.92e-04, 1.09e-04, 1.76e-04, 1.50e+01]    [2.50e-02]
# 22000     [5.59e-01, 6.10e-03, 9.19e-05, 3.84e-07, 1.31e+01]    [7.08e-01, 6.10e-03, 9.19e-05, 3.84e-07, 1.31e+01]    [2.27e-02]
# 23000     [5.50e-01, 4.01e-03, 4.96e-05, 2.88e-07, 1.20e+01]    [9.45e-01, 4.01e-03, 4.96e-05, 2.88e-07, 1.20e+01]    [2.17e-02]
# 24000     [4.86e-01, 5.17e-03, 5.30e-05, 2.29e-07, 1.06e+01]    [5.40e-01, 5.17e-03, 5.30e-05, 2.29e-07, 1.06e+01]    [2.03e-02]
# 25000     [4.72e-01, 4.71e-03, 2.83e-05, 3.28e-10, 9.80e+00]    [5.30e-01, 4.71e-03, 2.83e-05, 3.28e-10, 9.80e+00]    [1.94e-02]
# 26000     [8.14e-01, 4.27e-03, 2.00e-05, 5.62e-06, 8.78e+00]    [1.28e+00, 4.27e-03, 2.00e-05, 5.62e-06, 8.78e+00]    [1.82e-02]
# 27000     [4.39e-01, 4.19e-03, 1.05e-05, 1.73e-08, 8.15e+00]    [3.43e-01, 4.19e-03, 1.05e-05, 1.73e-08, 8.15e+00]    [1.75e-02]
# 28000     [2.02e+00, 1.11e-03, 8.17e-06, 2.31e-04, 7.59e+00]    [1.85e+00, 1.11e-03, 8.17e-06, 2.31e-04, 7.59e+00]    [1.69e-02]
# 29000     [4.33e+01, 2.80e-04, 2.06e-07, 3.34e-04, 7.00e+00]    [6.05e+01, 2.80e-04, 2.06e-07, 3.34e-04, 7.00e+00]    [1.64e-02]
# 30000     [3.98e-01, 3.40e-03, 9.64e-08, 8.52e-08, 6.31e+00]    [1.79e-01, 3.40e-03, 9.64e-08, 8.52e-08, 6.31e+00]    [1.52e-02]
# 31000     [4.03e-01, 2.58e-03, 1.71e-06, 2.51e-08, 5.93e+00]    [1.55e-01, 2.58e-03, 1.71e-06, 2.51e-08, 5.93e+00]    [1.47e-02]
# 32000     [1.86e+00, 7.72e-05, 1.17e-04, 3.17e-04, 5.60e+00]    [1.53e+00, 7.72e-05, 1.17e-04, 3.17e-04, 5.60e+00]    [1.42e-02]
# 33000     [3.82e-01, 2.85e-03, 9.37e-06, 1.27e-06, 5.20e+00]    [1.38e-01, 2.85e-03, 9.37e-06, 1.27e-06, 5.20e+00]    [1.36e-02]
# 34000     [4.13e+01, 1.15e-04, 2.13e-06, 5.59e-03, 4.90e+00]    [5.97e+01, 1.15e-04, 2.13e-06, 5.59e-03, 4.90e+00]    [1.35e-02]
# 35000     [9.37e+01, 6.08e-04, 6.60e-05, 7.06e-04, 4.79e+00]    [1.37e+02, 6.08e-04, 6.60e-05, 7.06e-04, 4.79e+00]    [1.31e-02]
# 36000     [3.35e-01, 2.76e-03, 2.39e-05, 7.80e-07, 4.23e+00]    [1.55e-01, 2.76e-03, 2.39e-05, 7.80e-07, 4.23e+00]    [1.22e-02]
# 37000     [3.36e-01, 2.32e-03, 3.31e-05, 1.48e-06, 4.01e+00]    [1.74e-01, 2.32e-03, 3.31e-05, 1.48e-06, 4.01e+00]    [1.18e-02]
# 38000     [4.00e-01, 3.42e-04, 7.71e-05, 2.93e-06, 3.87e+00]    [2.11e-01, 3.42e-04, 7.71e-05, 2.93e-06, 3.87e+00]    [1.16e-02]
# 39000     [4.58e-01, 2.61e-03, 3.78e-05, 6.56e-06, 3.54e+00]    [4.75e-01, 2.61e-03, 3.78e-05, 6.56e-06, 3.54e+00]    [1.10e-02]
# 40000     [3.32e-01, 2.40e-03, 5.08e-05, 2.36e-06, 3.42e+00]    [2.83e-01, 2.40e-03, 5.08e-05, 2.36e-06, 3.42e+00]    [1.08e-02]
# 41000     [3.68e+00, 2.15e-06, 2.04e-04, 5.03e-07, 3.35e+00]    [4.14e+00, 2.15e-06, 2.04e-04, 5.03e-07, 3.35e+00]    [1.07e-02]
# 42000     [3.38e+00, 5.36e-07, 1.43e-04, 7.22e-07, 3.19e+00]    [5.36e+00, 5.36e-07, 1.43e-04, 7.22e-07, 3.19e+00]    [1.06e-02]
# 43000     [6.04e-01, 2.39e-03, 5.55e-05, 1.48e-05, 2.92e+00]    [1.06e+00, 2.39e-03, 5.55e-05, 1.48e-05, 2.92e+00]    [9.94e-03]
# 44000     [3.91e+01, 7.72e-05, 1.79e-08, 5.78e-03, 2.91e+00]    [5.78e+01, 7.72e-05, 1.79e-08, 5.78e-03, 2.91e+00]    [1.03e-02]
# 45000     [2.22e+02, 2.16e-03, 2.95e-05, 6.59e-03, 2.79e+00]    [3.21e+02, 2.16e-03, 2.95e-05, 6.59e-03, 2.79e+00]    [1.01e-02]
# 46000     [3.03e-01, 1.89e-03, 7.39e-05, 2.25e-06, 2.59e+00]    [7.23e-01, 1.89e-03, 7.39e-05, 2.25e-06, 2.59e+00]    [9.32e-03]
# 47000     [3.13e-01, 1.50e-03, 7.80e-05, 3.55e-06, 2.51e+00]    [8.21e-01, 1.50e-03, 7.80e-05, 3.55e-06, 2.51e+00]    [9.17e-03]
# 48000     [2.76e+00, 1.01e-05, 1.38e-04, 1.19e-04, 2.48e+00]    [3.31e+00, 1.01e-05, 1.38e-04, 1.19e-04, 2.48e+00]    [9.12e-03]
# 49000     [2.96e-01, 1.88e-03, 7.35e-05, 1.56e-06, 2.29e+00]    [1.06e+00, 1.88e-03, 7.35e-05, 1.56e-06, 2.29e+00]    [8.72e-03]
# 50000     [3.13e-01, 1.12e-03, 7.82e-05, 3.84e-06, 2.26e+00]    [1.16e+00, 1.12e-03, 7.82e-05, 3.84e-06, 2.26e+00]    [8.67e-03]
#
# Best model at step 50000:
#   train loss: 2.58e+00
#   test loss: 3.42e+00
#   test metric: [8.67e-03]
#
# 'train' took 222.386066 s

# %% [markdown]
# ## Evaluation
#
# Visualize and save the loss history.

# %%
# disable latex for deepxde plots
plt.rc('text', usetex=False)

dde.saveplot(
  loss_history,
  train_state,
  issave=True,
  isplot=True,
  output_dir="data/joint"
)

plt.rc('text', usetex=True)
# Out:
# Saving loss history to data/joint/loss.dat ...
# Saving training data to data/joint/train.dat ...
# Saving test data to data/joint/test.dat ...

# %% [markdown]
# Generate predictions using the trained model and true values from the `true_solution` function.

# %%
t_test = np.linspace(scale_time(T0), scale_time(TF), 100)

y_pred = model.predict(t_test.reshape(-1, 1))
S_pred, I_pred, R_pred = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]

S_true, I_true, R_true = true_solution(t_test.reshape(-1, 1)).T

# %% [markdown]
# Unscale the data for visualization.

# %%
t_test = unscale_time(t_test)
S_true = unscale_population(S_true)
I_true = unscale_population(I_true)
R_true = unscale_population(R_true)

S_pred = unscale_population(S_pred)
I_pred = unscale_population(I_pred)
R_pred = unscale_population(R_pred)

# %% [markdown]
# Plot the true solution and the predicted solution.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_test, y=S_true, label="$S_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=S_pred, label="$S_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=I_true, label="$I_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=I_pred, label="$I_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=R_true, label="$R_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=R_pred, label="$R_{\mathrm{pred}}$", linestyle="--")

plt.xlabel("Time (days)")
plt.ylabel("Population")
plt.title("PINN Prediction vs True Solution")
plt.legend()
plt.savefig("data/joint/predictions.png")
plt.show()
