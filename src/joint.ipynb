# %% [markdown]
# # SIR model - Joint Approach
#
# Solving the SIR model with constant transmission rate $\beta$ and recovery rate $\delta$.
#
# $$
# \begin{cases}
# \frac{dS}{dt} &= -\frac{\beta}{N} I S, \\
# \frac{dI}{dt} &= \frac{\beta}{N} I S - \delta I, \\
# \frac{dR}{dt} &= \delta I,
# \end{cases}
# $$
#
# where $t \in [0, 90]$ and with the initial conditions $S(0) = N - 1$, $I(0) = 1$, and $R(0) = 0$.

# %% [markdown]
# ## Environment Setup
#
# Load .env file, which specifies which backend DeepXDE should use

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import torch
import deepxde as dde
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.interpolate import interp1d

# %% [markdown]
# Enable latex in matplotlib and set seaborn theme.

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sns.set_theme(style="darkgrid")

# %% [markdown]
# Set random seed for reproducibility

# %%
seed = 2322

np.random.seed(seed)
torch.manual_seed(seed)
dde.config.set_random_seed(seed)

# %% [markdown]
# ## Synthetic data generation
#
# Building a SIR model to generate a discrete synthetic dataset in a closed time interval.
#
# This dataset will be used as a starting point for creating both the true solution used during the l2 regularization term and observed data used during the training of the network.
#
# ### System configuration
#
# The following parameters are used (using Italy as reference):

# %%
N = 56e6  # total population
delta = 1 / 5  # recovery rate (1 / mean infectious period)
r0 = 3.0  # basic reproduction number
beta = delta * r0  # transmission rate

# %% [markdown]
# The following time interval is used:

# %%
T0, TF = 0, 90  # (days)

# %% [markdown]
# ### System definition
#
# Define the SIR model and the initial conditions.

# %%
def SIR(x, t, delta, beta, N):
  S, I, R = x
  _lambda = beta * I / N
  dSdt = -_lambda * S
  dIdt = _lambda * S - delta * I
  dRdt = delta * I
  return [dSdt, dIdt, dRdt]


S0 = N - 1
I0 = 1
R0 = 0

# %% [markdown]
# Define a function to generate a discrete solution for the SIR model based on a time interval.

# %%
def solve_sir(t):
  x = odeint(SIR, [S0, I0, R0], t, args=(delta, beta, N))
  S = x[:, 0]
  I = x[:, 1]
  R = x[:, 2]
  return S, I, R

# %% [markdown]
# ### Data generation
#
# Generate a synthetic dataset and a synthetic observation of $I(t)$ by adding some noise to the true solution.

# %%
t_train = np.linspace(T0, TF, TF - T0)
S_data, I_data, R_data = solve_sir(t_train)

I_train = np.random.poisson(I_data)

# %% [markdown]
# Plot the synthetic dataset and the observed $I(t)$.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_train, y=S_data, label=r"$S(t)$")
sns.lineplot(x=t_train, y=I_data, label=r"$I(t)$")
sns.lineplot(x=t_train, y=R_data, label=r"$R(t)$")
sns.scatterplot(x=t_train, y=I_train, label=r"Observed $I(t)$")

plt.title(
  r"SIR Model with $\beta = {:.2f}$ and $\delta = {:.2f}$".format(beta, delta)
)
plt.xlabel(r"Time (days)")
plt.ylabel(r"Population")

plt.savefig("data/synthetic_data.png")

# %% [markdown]
# ## Data Scaling
#
# Scale both dataset and observation by a constant $C$ and into a time interval $[0, 1]$.
#
# This is necessary to avoid numerical instability during the training of the network.
#
# Define the scaling and unscaling functions.

# %%
C = 1e5


def scale_time(t):
  return t / TF


def unscale_time(t):
  return t * TF


def scale_population(x):
  return x / C


def unscale_population(x):
  return x * C

# %% [markdown]
# From now on, we will only use the scaled data.

# %%
t_train = scale_time(t_train.reshape(-1, 1))

I_train = scale_population(I_train.reshape(-1, 1))

# %% [markdown]
# ## True Solution
#
# Create a function to compute the true solution for any time point.
#
# It uses an interpolation function applied on a more dense time interval.

# %%
t_dense = np.linspace(T0, TF, 1000)
S_dense, I_dense, R_dense = solve_sir(t_dense)

t_dense = scale_time(t_dense)
S_dense = scale_population(S_dense)
I_dense = scale_population(I_dense)
R_dense = scale_population(R_dense)

S_interp = interp1d(t_dense, S_dense, kind='cubic', fill_value="extrapolate")
I_interp = interp1d(t_dense, I_dense, kind='cubic', fill_value="extrapolate")
R_interp = interp1d(t_dense, R_dense, kind='cubic', fill_value="extrapolate")


def true_solution(t):
  t = t.flatten()
  S = S_interp(t)
  I = I_interp(t)
  R = R_interp(t)
  return np.hstack((S.reshape(-1, 1), I.reshape(-1, 1), R.reshape(-1, 1)))

# %% [markdown]
# ## Modelling a Joint Network
#
# Define a PINN that tries to solve the SIR model by reducing at the same time the error generated by the observed data, the error generated by the ODE system, and the error generated by initial conditions mismatch.
#
# ### Network configuration

# %%
layer_size = [1] + [50] * 3 + [3]
activation = "tanh"
initializer = "Glorot uniform"

optimizer = "adam"
lr = 0.001

iterations = 50000

# %% [markdown]
# ### Network definition
#
# Define the time domain geometry, scaled to the range [0, 1].

# %%
geom = dde.geometry.TimeDomain(scale_time(T0), scale_time(TF))

# %% [markdown]
# Define the beta parameter as a trainable variable with initial guess.

# %%
beta_var = dde.Variable(0.5)

# %% [markdown]
# Define the ODE system, adjusted to use the scaled data.

# %%
C1 = (TF - T0) * C / N
C2 = (TF - T0) * delta


def ode_system(t, y):
  S = y[:, 0:1]
  I = y[:, 1:2]
  _R = y[:, 2:3]
  dS_t = dde.grad.jacobian(y, t, i=0)
  dI_t = dde.grad.jacobian(y, t, i=1)
  dR_t = dde.grad.jacobian(y, t, i=2)

  res_s = dS_t - (- C1 * beta_var * I * S)
  res_i = dI_t - (C1 * beta_var * I * S - C2 * I)
  res_r = dR_t - (C2 * I)
  return torch.cat([res_s, res_i, res_r], dim=1)

# %% [markdown]
# Define the initial condition.

# %%
def boundary(_, on_initial):
  return on_initial


ic_S = dde.icbc.IC(geom, lambda t: scale_population(S0), boundary, component=0)
ic_I = dde.icbc.IC(geom, lambda t: scale_population(I0), boundary, component=1)
ic_R = dde.icbc.IC(geom, lambda t: scale_population(R0), boundary, component=2)

# %% [markdown]
# Define the boundary condition using the observed $I(t)$ data.

# %%
observe_I = dde.icbc.PointSetBC(t_train, I_train, component=1)

# %% [markdown]
# Define the ODE problem with the ICs and BCs.
#
# We use 2000 points inside the domain and 2 points on the boundary (the start and the end of the time domain).
#
# We use the synthetic (and scaled) time domain to define the points where the data is observed.

# %%
data = dde.data.PDE(
  geom,
  ode_system,
  [ic_S, ic_I, ic_R, observe_I],
  num_domain=90,
  num_boundary=2,
  anchors=t_train,
  solution=true_solution,
  num_test=10
)

# %% [markdown]
# Define the network.

# %%
net = dde.nn.FNN(layer_size, activation, initializer)

# %% [markdown]
# Define the model, including the beta parameter as an external trainable variable.

# %%
model = dde.Model(data, net)

model.compile(
  optimizer=optimizer,
  lr=lr,
  loss_weights=[1] * 5,
  external_trainable_variables=[beta_var],
  metrics=["l2 relative error"]
)
# Out:
# Compiling model...
# 'compile' took 0.000398 s

# %% [markdown]
# Train the model.

# %%
loss_history, train_state = model.train(iterations=iterations)
# Out:
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 0         [6.90e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [6.70e-02, 3.14e+05, 1.00e-10, 0.00e+00, 3.18e+03]    [1.00e+00]
# 1000      [5.27e+00, 2.47e+05, 3.45e-02, 8.48e-05, 3.17e+03]    [5.27e+00, 2.47e+05, 3.45e-02, 8.48e-05, 3.17e+03]    [9.31e-01]
# 2000      [5.33e+00, 2.01e+05, 3.53e-02, 2.28e-05, 3.17e+03]    [5.34e+00, 2.01e+05, 3.53e-02, 2.28e-05, 3.17e+03]    [8.87e-01]
# 3000      [8.42e+00, 1.61e+05, 9.00e-02, 3.98e-06, 3.16e+03]    [7.90e+00, 1.61e+05, 9.00e-02, 3.98e-06, 3.16e+03]    [8.49e-01]
# 4000      [4.18e+01, 1.26e+05, 4.52e-02, 1.00e-04, 2.97e+03]    [4.49e+01, 1.26e+05, 4.52e-02, 1.00e-04, 2.97e+03]    [7.95e-01]
# 5000      [7.97e+01, 9.63e+04, 4.13e-02, 6.27e-06, 2.83e+03]    [8.53e+01, 9.63e+04, 4.13e-02, 6.27e-06, 2.83e+03]    [7.51e-01]
# 6000      [1.08e+02, 7.09e+04, 1.37e-01, 2.57e-06, 2.66e+03]    [1.16e+02, 7.09e+04, 1.37e-01, 2.57e-06, 2.66e+03]    [6.97e-01]
# 7000      [1.21e+02, 4.99e+04, 2.55e-01, 1.01e-05, 2.52e+03]    [1.28e+02, 4.99e+04, 2.55e-01, 1.01e-05, 2.52e+03]    [6.56e-01]
# 8000      [1.36e+02, 3.31e+04, 3.47e-01, 7.56e-07, 2.39e+03]    [1.43e+02, 3.31e+04, 3.47e-01, 7.56e-07, 2.39e+03]    [6.19e-01]
# 9000      [1.50e+02, 2.02e+04, 2.80e-01, 9.03e-09, 2.28e+03]    [1.60e+02, 2.02e+04, 2.80e-01, 9.03e-09, 2.28e+03]    [5.97e-01]
# 10000     [1.45e+02, 1.10e+04, 2.93e-01, 3.30e-07, 2.14e+03]    [1.53e+02, 1.10e+04, 2.93e-01, 3.30e-07, 2.14e+03]    [5.65e-01]
# 11000     [1.43e+02, 4.98e+03, 3.21e-01, 1.41e-07, 2.08e+03]    [1.51e+02, 4.98e+03, 3.21e-01, 1.41e-07, 2.08e+03]    [5.59e-01]
# 12000     [1.38e+02, 1.70e+03, 3.75e-01, 5.39e-07, 2.03e+03]    [1.45e+02, 1.70e+03, 3.75e-01, 5.39e-07, 2.03e+03]    [5.58e-01]
# 13000     [1.34e+02, 3.53e+02, 4.12e-01, 4.60e-10, 1.98e+03]    [1.39e+02, 3.53e+02, 4.12e-01, 4.60e-10, 1.98e+03]    [5.59e-01]
# 14000     [1.16e+02, 3.07e+01, 3.93e-01, 7.94e-08, 1.86e+03]    [1.21e+02, 3.07e+01, 3.93e-01, 7.94e-08, 1.86e+03]    [5.27e-01]
# 15000     [1.18e+02, 2.15e-01, 3.33e-01, 1.27e-07, 1.82e+03]    [1.27e+02, 2.15e-01, 3.33e-01, 1.27e-07, 1.82e+03]    [5.21e-01]
# 16000     [1.16e+02, 1.37e-01, 3.03e-01, 1.79e-05, 1.78e+03]    [1.25e+02, 1.37e-01, 3.03e-01, 1.79e-05, 1.78e+03]    [5.11e-01]
# 17000     [7.76e+01, 2.56e-02, 4.62e-01, 4.11e-07, 1.65e+03]    [8.19e+01, 2.56e-02, 4.62e-01, 4.11e-07, 1.65e+03]    [4.67e-01]
# 18000     [8.92e+01, 5.90e-03, 1.57e-01, 3.78e-08, 1.53e+03]    [9.67e+01, 5.90e-03, 1.57e-01, 3.78e-08, 1.53e+03]    [4.40e-01]
# 19000     [7.73e+01, 6.42e-02, 1.01e-01, 1.78e-07, 1.41e+03]    [8.06e+01, 6.42e-02, 1.01e-01, 1.78e-07, 1.41e+03]    [4.07e-01]
# 20000     [6.35e+01, 3.43e-01, 6.00e-02, 1.33e-06, 1.27e+03]    [6.34e+01, 3.43e-01, 6.00e-02, 1.33e-06, 1.27e+03]    [3.70e-01]
# 21000     [2.74e+01, 5.62e-01, 1.55e-01, 1.15e-06, 1.08e+03]    [1.87e+01, 5.62e-01, 1.55e-01, 1.15e-06, 1.08e+03]    [3.16e-01]
# 22000     [3.11e+01, 6.81e-01, 1.42e-02, 2.50e-06, 8.93e+02]    [2.78e+01, 6.81e-01, 1.42e-02, 2.50e-06, 8.93e+02]    [2.77e-01]
# 23000     [2.04e+01, 7.00e-01, 6.79e-03, 3.06e-06, 7.49e+02]    [1.81e+01, 7.00e-01, 6.79e-03, 3.06e-06, 7.49e+02]    [2.43e-01]
# 24000     [1.33e+01, 5.90e-01, 3.64e-03, 1.00e-10, 6.19e+02]    [1.05e+01, 5.90e-01, 3.64e-03, 1.00e-10, 6.19e+02]    [2.12e-01]
# 25000     [1.18e+01, 4.38e-01, 1.73e-03, 3.25e-06, 5.03e+02]    [1.22e+01, 4.38e-01, 1.73e-03, 3.25e-06, 5.03e+02]    [1.83e-01]
# 26000     [1.66e+01, 2.92e-01, 1.05e-03, 5.91e-06, 4.04e+02]    [1.16e+01, 2.92e-01, 1.05e-03, 5.91e-06, 4.04e+02]    [1.58e-01]
# 27000     [9.47e+00, 1.87e-01, 4.60e-04, 3.02e-06, 3.20e+02]    [1.28e+01, 1.87e-01, 4.60e-04, 3.02e-06, 3.20e+02]    [1.36e-01]
# 28000     [7.00e+00, 1.15e-01, 2.74e-04, 7.48e-06, 2.51e+02]    [1.36e+01, 1.15e-01, 2.74e-04, 7.48e-06, 2.51e+02]    [1.17e-01]
# 29000     [4.59e+00, 5.23e-02, 2.35e-04, 4.77e-07, 1.89e+02]    [8.05e+00, 5.23e-02, 2.35e-04, 4.77e-07, 1.89e+02]    [9.91e-02]
# 30000     [3.66e+00, 3.12e-02, 1.41e-04, 1.27e-08, 1.40e+02]    [2.73e+00, 3.12e-02, 1.41e-04, 1.27e-08, 1.40e+02]    [8.34e-02]
# 31000     [1.64e+01, 2.43e-02, 1.46e-05, 8.27e-06, 1.04e+02]    [2.64e+01, 2.43e-02, 1.46e-05, 8.27e-06, 1.04e+02]    [7.05e-02]
# 32000     [2.23e+00, 1.64e-02, 5.02e-05, 1.80e-09, 7.83e+01]    [7.81e-01, 1.64e-02, 5.02e-05, 1.80e-09, 7.83e+01]    [6.00e-02]
# 33000     [2.16e+00, 1.22e-02, 2.88e-05, 5.90e-07, 5.86e+01]    [1.64e+00, 1.22e-02, 2.88e-05, 5.90e-07, 5.86e+01]    [5.10e-02]
# 34000     [8.26e+00, 8.61e-03, 1.55e-06, 3.01e-06, 4.39e+01]    [2.18e+01, 8.61e-03, 1.55e-06, 3.01e-06, 4.39e+01]    [4.37e-02]
# 35000     [1.47e+01, 6.19e-03, 2.05e-06, 1.02e-05, 3.32e+01]    [3.78e+01, 6.19e-03, 2.05e-06, 1.02e-05, 3.32e+01]    [3.76e-02]
# 36000     [5.72e+00, 3.53e-03, 1.95e-05, 1.98e-07, 2.55e+01]    [4.02e+00, 3.53e-03, 1.95e-05, 1.98e-07, 2.55e+01]    [3.27e-02]
# 37000     [1.25e+00, 2.53e-03, 6.27e-06, 8.65e-09, 1.96e+01]    [3.43e+00, 2.53e-03, 6.27e-06, 8.65e-09, 1.96e+01]    [2.85e-02]
# 38000     [1.94e+00, 1.82e-03, 5.62e-06, 1.10e-07, 1.51e+01]    [5.68e+00, 1.82e-03, 5.62e-06, 1.10e-07, 1.51e+01]    [2.48e-02]
# 39000     [9.28e-01, 1.49e-03, 2.60e-06, 2.70e-09, 1.17e+01]    [2.17e+00, 1.49e-03, 2.60e-06, 2.70e-09, 1.17e+01]    [2.17e-02]
# 40000     [8.34e-01, 1.12e-03, 1.54e-06, 2.74e-08, 9.13e+00]    [1.41e+00, 1.12e-03, 1.54e-06, 2.74e-08, 9.13e+00]    [1.90e-02]
# 41000     [7.33e-01, 9.02e-04, 1.32e-06, 2.27e-13, 7.13e+00]    [8.00e-01, 9.02e-04, 1.32e-06, 2.27e-13, 7.13e+00]    [1.67e-02]
# 42000     [7.93e-01, 5.87e-04, 1.81e-07, 4.24e-07, 5.58e+00]    [8.87e-01, 5.87e-04, 1.81e-07, 4.24e-07, 5.58e+00]    [1.47e-02]
# 43000     [7.08e-01, 4.59e-04, 1.14e-06, 1.46e-08, 4.38e+00]    [3.63e-01, 4.59e-04, 1.14e-06, 1.46e-08, 4.38e+00]    [1.30e-02]
# 44000     [5.52e-01, 4.46e-04, 3.52e-07, 1.65e-08, 3.43e+00]    [2.98e-01, 4.46e-04, 3.52e-07, 1.65e-08, 3.43e+00]    [1.14e-02]
# 45000     [1.42e+00, 3.29e-04, 3.35e-07, 1.57e-06, 2.69e+00]    [1.86e+00, 3.29e-04, 3.35e-07, 1.57e-06, 2.69e+00]    [1.01e-02]
# 46000     [6.29e+00, 3.70e-04, 5.89e-06, 1.03e-05, 2.10e+00]    [8.34e+00, 3.70e-04, 5.89e-06, 1.03e-05, 2.10e+00]    [8.80e-03]
# 47000     [4.57e-01, 1.75e-04, 4.78e-08, 8.77e-08, 1.68e+00]    [5.75e-01, 1.75e-04, 4.78e-08, 8.77e-08, 1.68e+00]    [7.93e-03]
# 48000     [9.49e+00, 1.19e-04, 1.28e-05, 8.22e-06, 1.37e+00]    [1.45e+01, 1.19e-04, 1.28e-05, 8.22e-06, 1.37e+00]    [7.30e-03]
# 49000     [2.42e+00, 9.78e-05, 3.74e-06, 1.20e-06, 1.07e+00]    [3.41e+00, 9.78e-05, 3.74e-06, 1.20e-06, 1.07e+00]    [6.34e-03]
# 50000     [3.33e-01, 1.00e-04, 3.07e-10, 1.60e-08, 8.43e-01]    [4.33e-01, 1.00e-04, 3.07e-10, 1.60e-08, 8.43e-01]    [5.58e-03]
#
# Best model at step 50000:
#   train loss: 1.18e+00
#   test loss: 1.28e+00
#   test metric: [5.58e-03]
#
# 'train' took 116.995807 s

# %% [markdown]
# ## Evaluation
#
# Visualize and save the loss history.

# %%
# disable latex for deepxde plots
plt.rc('text', usetex=False)

dde.saveplot(
  loss_history,
  train_state,
  issave=True,
  isplot=True,
  output_dir="data"
)

plt.rc('text', usetex=True)
# Out:
# Saving loss history to data/loss.dat ...
# Saving training data to data/train.dat ...
# Saving test data to data/test.dat ...

# %% [markdown]
# Generate predictions using the trained model and true values from the `true_solution` function.

# %%
t_test = np.linspace(scale_time(T0), scale_time(TF), 100)

y_pred = model.predict(t_test.reshape(-1, 1))
S_pred, I_pred, R_pred = y_pred[:, 0], y_pred[:, 1], y_pred[:, 2]

S_true, I_true, R_true = true_solution(t_test.reshape(-1, 1)).T

# %% [markdown]
# Unscale the data for visualization.

# %%
t_test = unscale_time(t_test)
S_true = unscale_population(S_true)
I_true = unscale_population(I_true)
R_true = unscale_population(R_true)

S_pred = unscale_population(S_pred)
I_pred = unscale_population(I_pred)
R_pred = unscale_population(R_pred)

# %% [markdown]
# Plot the true solution and the predicted solution.

# %%
plt.subplots(figsize=(12, 6))

sns.lineplot(x=t_test, y=S_true, label="$S_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=S_pred, label="$S_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=I_true, label="$I_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=I_pred, label="$I_{\mathrm{pred}}$", linestyle="--")
sns.lineplot(x=t_test, y=R_true, label="$R_{\mathrm{true}}$")
sns.lineplot(x=t_test, y=R_pred, label="$R_{\mathrm{pred}}$", linestyle="--")

plt.xlabel("Time (days)")
plt.ylabel("Population")
plt.title("PINN Prediction vs True Solution")
plt.legend()
plt.savefig("data/predictions.png")
plt.show()
